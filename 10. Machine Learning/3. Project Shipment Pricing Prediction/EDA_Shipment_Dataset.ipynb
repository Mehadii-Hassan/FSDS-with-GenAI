# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/shipment.csv.csv")

# %% [markdown]
# # Basic Overview

# %%
df.head()
# Out:
#             Customer Id     Artist Name  Artist Reputation  Height  Width  \
# 0  fffe3900350033003300   Billy Jenkins               0.26    17.0    6.0
# 1  fffe3800330031003900     Jean Bryant               0.28     3.0    3.0
# 2  fffe3600370035003100    Laura Miller               0.07     8.0    5.0
# 3      fffe350031003300  Robert Chaires               0.12     9.0    NaN
# 4  fffe3900320038003400    Rosalyn Krol               0.15    17.0    6.0
#
#    Weight   Material  Price Of Sculpture  Base Shipping Price International  \
# 0  4128.0      Brass               13.91                16.27           Yes
# 1    61.0      Brass                6.83                15.00            No
# 2   237.0       Clay                4.96                21.18            No
# 3     NaN  Aluminium                5.81                16.31            No
# 4   324.0  Aluminium                3.18                11.94           Yes
#
#   Express Shipment Installation Included Transport Fragile  \
# 0              Yes                    No   Airways      No
# 1               No                    No  Roadways      No
# 2               No                    No  Roadways     Yes
# 3               No                    No       NaN      No
# 4              Yes                   Yes   Airways      No
#
#   Customer Information Remote Location Scheduled Date Delivery Date  \
# 0        Working Class              No       06/07/15      06/03/15
# 1        Working Class              No       03/06/17      03/05/17
# 2        Working Class             Yes       03/09/15      03/08/15
# 3              Wealthy             Yes       05/24/15      05/20/15
# 4        Working Class              No       12/18/16      12/14/16
#
#            Customer Location    Cost
# 0     New Michelle, OH 50777 -283.29
# 1  New Michaelport, WY 12072 -159.96
# 2      Bowmanshire, WA 19241 -154.29
# 3       East Robyn, KY 86375 -161.16
# 4        Aprilside, PA 52793 -159.23

# %%
df.tail()
# Out:
#                Customer Id          Artist Name  Artist Reputation  Height  \
# 6495  fffe3800370037003300  Jeffrey Freudenthal               0.37    37.0
# 6496      fffe310036003400        Larry Edwards               0.67    15.0
# 6497  fffe3600300031003300         Denise Worth               0.68    19.0
# 6498  fffe3600350035003900          Daniel Drew               0.02    33.0
# 6499  fffe3700310031003600       Vernon Carroll               0.18    30.0
#
#       Width     Weight Material  Price Of Sculpture  Base Shipping Price  \
# 6495   10.0    16551.0    Brass               28.28                38.46
# 6496    NaN    18981.0      NaN               67.18                27.72
# 6497    8.0      587.0     Clay                6.92                10.38
# 6498    9.0  1269377.0    Stone             2929.13                69.76
# 6499   13.0    34729.0    Brass               46.63                78.25
#
#      International Express Shipment Installation Included Transport Fragile  \
# 6495           Yes              Yes                    No   Airways      No
# 6496            No               No                    No  Roadways      No
# 6497           Yes               No                    No       NaN     Yes
# 6498            No              Yes                    No  Roadways      No
# 6499            No              Yes                    No   Airways      No
#
#      Customer Information Remote Location Scheduled Date Delivery Date  \
# 6495              Wealthy             Yes       03/28/18      03/25/18
# 6496        Working Class              No       08/29/15      08/27/15
# 6497              Wealthy              No       04/10/19      04/09/19
# 6498        Working Class             Yes       03/10/19      03/12/19
# 6499        Working Class              No       12/03/16      12/05/16
#
#               Customer Location     Cost
# 6495       New Robert, VT 85335   872.43
# 6496       New Joshua, VA 35766  1347.02
# 6497       Lake Kelly, MA 80823   354.55
# 6498       Hintonberg, UT 35006  5037.50
# 6499  New Christopher, AK 87406   722.47

# %%
df.sample(5)
# Out:
#                Customer Id     Artist Name  Artist Reputation  Height  Width  \
# 3806  fffe3100370035003800      Diane Fine               0.58     5.0    5.0
# 5354  fffe3200310033003200  David Mckinney               0.58     8.0    5.0
# 6367  fffe3600360039003800    Robert Davis               0.14    13.0    7.0
# 248   fffe3100350034003300  Thomas Gritton               0.37     9.0    NaN
# 431       fffe340030003000      Guy Wilkie                NaN    27.0   13.0
#
#       Weight   Material  Price Of Sculpture  Base Shipping Price  \
# 3806   265.0     Bronze                5.06                16.39
# 5354   209.0       Clay                5.56                12.43
# 6367  4621.0      Brass               20.43                20.88
# 248      NaN        NaN                4.41                23.94
# 431      NaN  Aluminium               10.71                17.49
#
#      International Express Shipment Installation Included Transport Fragile  \
# 3806           Yes              Yes                   Yes   Airways      No
# 5354            No               No                    No   Airways     Yes
# 6367            No               No                   Yes  Roadways      No
# 248            Yes               No                   Yes       NaN      No
# 431             No               No                    No       NaN      No
#
#      Customer Information Remote Location Scheduled Date Delivery Date  \
# 3806        Working Class              No       03/12/15      03/10/15
# 5354        Working Class              No       10/31/17      11/01/17
# 6367        Working Class             Yes       04/23/19      04/19/19
# 248         Working Class              No       06/03/18      06/01/18
# 431         Working Class             Yes       06/19/18      06/17/18
#
#               Customer Location    Cost
# 3806    Waltonchester, HI 84750  277.58
# 5354      Garciaburgh, MO 91846  187.89
# 6367       Brendabury, LA 89291  267.67
# 248   South Evanburgh, RI 81242 -227.45
# 431         Katiebury, NM 93659 -872.08

# %%
df.shape
# Out:
# (6500, 20)

# %%
df.columns
# Out:
# Index(['Customer Id', 'Artist Name', 'Artist Reputation', 'Height', 'Width',
#        'Weight', 'Material', 'Price Of Sculpture', 'Base Shipping Price',
#        'International', 'Express Shipment', 'Installation Included',
#        'Transport', 'Fragile', 'Customer Information', 'Remote Location',
#        'Scheduled Date', 'Delivery Date', 'Customer Location', 'Cost'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6500, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6500 entries, 0 to 6499
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer Id            6500 non-null   object
#  1   Artist Name            6500 non-null   object
#  2   Artist Reputation      5750 non-null   float64
#  3   Height                 6125 non-null   float64
#  4   Width                  5916 non-null   float64
#  5   Weight                 5913 non-null   float64
#  6   Material               5736 non-null   object
#  7   Price Of Sculpture     6500 non-null   float64
#  8   Base Shipping Price    6500 non-null   float64
#  9   International          6500 non-null   object
#  10  Express Shipment       6500 non-null   object
#  11  Installation Included  6500 non-null   object
#  12  Transport              5108 non-null   object
#  13  Fragile                6500 non-null   object
#  14  Customer Information   6500 non-null   object
#  15  Remote Location        5729 non-null   object
#  16  Scheduled Date         6500 non-null   object
#  17  Delivery Date          6500 non-null   object
#  18  Customer Location      6500 non-null   object
#  19  Cost                   6500 non-null   float64
# dtypes: float64(7), object(13)
# memory usage: 1015.8+ KB

# %%
df.dtypes
# Out:
# Customer Id               object
# Artist Name               object
# Artist Reputation        float64
# Height                   float64
# Width                    float64
# Weight                   float64
# Material                  object
# Price Of Sculpture       float64
# Base Shipping Price      float64
# International             object
# Express Shipment          object
# Installation Included     object
# Transport                 object
# Fragile                   object
# Customer Information      object
# Remote Location           object
# Scheduled Date            object
# Delivery Date             object
# Customer Location         object
# Cost                     float64
# dtype: object

# %%
df.describe()
# Out:
#        Artist Reputation       Height        Width        Weight  \
# count        5750.000000  6125.000000  5916.000000  5.913000e+03
# mean            0.461850    21.766204     9.617647  4.006948e+05
# std             0.265781    11.968192     5.417000  2.678081e+06
# min             0.000000     3.000000     2.000000  3.000000e+00
# 25%             0.240000    12.000000     6.000000  5.030000e+02
# 50%             0.450000    20.000000     8.000000  3.102000e+03
# 75%             0.680000    30.000000    12.000000  3.645600e+04
# max             1.000000    73.000000    50.000000  1.179279e+08
#
#        Price Of Sculpture  Base Shipping Price          Cost
# count          6500.00000          6500.000000  6.500000e+03
# mean           1192.42009            37.407174  1.713920e+04
# std            8819.61675            26.873519  2.406579e+05
# min               3.00000            10.000000 -8.801727e+05
# 25%               5.23000            16.700000  1.884400e+02
# 50%               8.02500            23.505000  3.820650e+02
# 75%              89.47000            57.905000  1.156115e+03
# max          382385.67000            99.980000  1.114343e+07

# %%
df.memory_usage()
# Out:
# Index                      132
# Customer Id              52000
# Artist Name              52000
# Artist Reputation        52000
# Height                   52000
# Width                    52000
# Weight                   52000
# Material                 52000
# Price Of Sculpture       52000
# Base Shipping Price      52000
# International            52000
# Express Shipment         52000
# Installation Included    52000
# Transport                52000
# Fragile                  52000
# Customer Information     52000
# Remote Location          52000
# Scheduled Date           52000
# Delivery Date            52000
# Customer Location        52000
# Cost                     52000
# dtype: int64

# %% [markdown]
# ## Key Insight from Basic Overview
#
# - The dataset comprises **6500 records and 20 features**.
# - There are **missing values** in several columns including `Artist Reputation`, `Height`, `Width`, `Weight`, `Material`, `Transport`, and `Remote Location`.
# - The `Scheduled Date` and `Delivery Date` columns are currently of **object type** and should be converted to datetime objects.
# - Numerical columns like `Weight`, `Price Of Sculpture`, and `Cost` show **wide value ranges**, with `Cost` even containing negative values, suggesting potential outliers or specific business logic (e.g., refunds, discounts) that need further examination.

# %% [markdown]
# # Data Cleaning Check

# %%
# Missing value check
df.isnull().sum()
# Out:
# Customer Id                 0
# Artist Name                 0
# Artist Reputation         750
# Height                    375
# Width                     584
# Weight                    587
# Material                  764
# Price Of Sculpture          0
# Base Shipping Price         0
# International               0
# Express Shipment            0
# Installation Included       0
# Transport                1392
# Fragile                     0
# Customer Information        0
# Remote Location           771
# Scheduled Date              0
# Delivery Date               0
# Customer Location           0
# Cost                        0
# dtype: int64

# %%
# Missing value percentage check
df.isna().mean() * 100
# Out:
# Customer Id               0.000000
# Artist Name               0.000000
# Artist Reputation        11.538462
# Height                    5.769231
# Width                     8.984615
# Weight                    9.030769
# Material                 11.753846
# Price Of Sculpture        0.000000
# Base Shipping Price       0.000000
# International             0.000000
# Express Shipment          0.000000
# Installation Included     0.000000
# Transport                21.415385
# Fragile                   0.000000
# Customer Information      0.000000
# Remote Location          11.861538
# Scheduled Date            0.000000
# Delivery Date             0.000000
# Customer Location         0.000000
# Cost                      0.000000
# dtype: float64

# %%
# Duplicate rows check
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Duplicate remove
df.drop_duplicates()
#or - df.drop_duplicates(inplace=True)
# Out:
#                Customer Id          Artist Name  Artist Reputation  Height  \
# 0     fffe3900350033003300        Billy Jenkins               0.26    17.0
# 1     fffe3800330031003900          Jean Bryant               0.28     3.0
# 2     fffe3600370035003100         Laura Miller               0.07     8.0
# 3         fffe350031003300       Robert Chaires               0.12     9.0
# 4     fffe3900320038003400         Rosalyn Krol               0.15    17.0
# ...                    ...                  ...                ...     ...
# 6495  fffe3800370037003300  Jeffrey Freudenthal               0.37    37.0
# 6496      fffe310036003400        Larry Edwards               0.67    15.0
# 6497  fffe3600300031003300         Denise Worth               0.68    19.0
# 6498  fffe3600350035003900          Daniel Drew               0.02    33.0
# 6499  fffe3700310031003600       Vernon Carroll               0.18    30.0
#
#       Width     Weight   Material  Price Of Sculpture  Base Shipping Price  \
# 0       6.0     4128.0      Brass               13.91                16.27
# 1       3.0       61.0      Brass                6.83                15.00
# 2       5.0      237.0       Clay                4.96                21.18
# 3       NaN        NaN  Aluminium                5.81                16.31
# 4       6.0      324.0  Aluminium                3.18                11.94
# ...     ...        ...        ...                 ...                  ...
# 6495   10.0    16551.0      Brass               28.28                38.46
# 6496    NaN    18981.0        NaN               67.18                27.72
# 6497    8.0      587.0       Clay                6.92                10.38
# 6498    9.0  1269377.0      Stone             2929.13                69.76
# 6499   13.0    34729.0      Brass               46.63                78.25
#
#      International Express Shipment Installation Included Transport Fragile  \
# 0              Yes              Yes                    No   Airways      No
# 1               No               No                    No  Roadways      No
# 2               No               No                    No  Roadways     Yes
# 3               No               No                    No       NaN      No
# 4              Yes              Yes                   Yes   Airways      No
# ...            ...              ...                   ...       ...     ...
# 6495           Yes              Yes                    No   Airways      No
# 6496            No               No                    No  Roadways      No
# 6497           Yes               No                    No       NaN     Yes
# 6498            No              Yes                    No  Roadways      No
# 6499            No              Yes                    No   Airways      No
#
#      Customer Information Remote Location Scheduled Date Delivery Date  \
# 0           Working Class              No       06/07/15      06/03/15
# 1           Working Class              No       03/06/17      03/05/17
# 2           Working Class             Yes       03/09/15      03/08/15
# 3                 Wealthy             Yes       05/24/15      05/20/15
# 4           Working Class              No       12/18/16      12/14/16
# ...                   ...             ...            ...           ...
# 6495              Wealthy             Yes       03/28/18      03/25/18
# 6496        Working Class              No       08/29/15      08/27/15
# 6497              Wealthy              No       04/10/19      04/09/19
# 6498        Working Class             Yes       03/10/19      03/12/19
# 6499        Working Class              No       12/03/16      12/05/16
#
#               Customer Location     Cost
# 0        New Michelle, OH 50777  -283.29
# 1     New Michaelport, WY 12072  -159.96
# 2         Bowmanshire, WA 19241  -154.29
# 3          East Robyn, KY 86375  -161.16
# 4           Aprilside, PA 52793  -159.23
# ...                         ...      ...
# 6495       New Robert, VT 85335   872.43
# 6496       New Joshua, VA 35766  1347.02
# 6497       Lake Kelly, MA 80823   354.55
# 6498       Hintonberg, UT 35006  5037.50
# 6499  New Christopher, AK 87406   722.47
#
# [6500 rows x 20 columns]

# %%
# Unique values check
df.nunique()
# Out:
# Customer Id              6500
# Artist Name              6449
# Artist Reputation         101
# Height                     65
# Width                      40
# Weight                   4410
# Material                    7
# Price Of Sculpture       3424
# Base Shipping Price      3732
# International               2
# Express Shipment            2
# Installation Included       2
# Transport                   3
# Fragile                     2
# Customer Information        2
# Remote Location             2
# Scheduled Date           1660
# Delivery Date            1664
# Customer Location        6500
# Cost                     6356
# dtype: int64

# %% [markdown]
# ## Key Insight from Data Cleaning Check
#
# - **Missing Values:** Several columns contain missing values, with `Transport` having the highest percentage (21.42%), followed by `Remote Location` (11.86%), `Material` (11.75%), `Artist Reputation` (11.54%), `Weight` (9.03%), `Width` (8.98%), and `Height` (5.77%). These missing values will need appropriate handling.
# - **Duplicate Rows:** The dataset contains **no duplicate rows**, which simplifies the cleaning process.
# - **Data Type Conversion:** As noted in the basic overview, `Scheduled Date` and `Delivery Date` are currently objects and must be converted to datetime format.
# - **Categorical Features:** Several columns (`Material`, `International`, `Express Shipment`, `Installation Included`, `Transport`, `Fragile`, `Customer Information`, `Remote Location`) are categorical and will need proper handling (e.g., encoding) if used in modeling.

# %% [markdown]
# #Variable Categorization

# %%
numerical_features = []
categorical_features = []

for column in df.columns:
    if df[column].dtype == "object":
        categorical_features.append(column)
    else:
        numerical_features.append(column)

print(f"Numerical Features ({len(numerical_features)}): {numerical_features}")
print(f"Categorical Features ({len(categorical_features)}): {categorical_features}")
# Out:
# Numerical Features (7): ['Artist Reputation', 'Height', 'Width', 'Weight', 'Price Of Sculpture', 'Base Shipping Price', 'Cost']
# Categorical Features (13): ['Customer Id', 'Artist Name', 'Material', 'International', 'Express Shipment', 'Installation Included', 'Transport', 'Fragile', 'Customer Information', 'Remote Location', 'Scheduled Date', 'Delivery Date', 'Customer Location']

# %% [markdown]
# ## Key Insight from Variable Categorization
#
# - **Numerical Features:** The dataset contains 7 numerical features: `Artist Reputation`, `Height`, `Width`, `Weight`, `Price Of Sculpture`, `Base Shipping Price`, and `Cost`. These are directly quantifiable and will be suitable for statistical analysis and numerical models, but missing values in some of these will need attention.
# - **Categorical Features:** There are 13 categorical features: `Customer Id`, `Artist Name`, `Material`, `International`, `Express Shipment`, `Installation Included`, `Transport`, `Fragile`, `Customer Information`, `Remote Location`, `Scheduled Date`, `Delivery Date`, and `Customer Location`. A significant number of these are nominal or binary. The date-related columns (`Scheduled Date`, `Delivery Date`) will specifically need conversion to datetime objects to extract temporal features or perform time-series analysis.

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# * The term univariate analysis refers to the analysis of one variable prefix “uni” means “one.” The purpose of univariate analysis is to understand the distribution of values for a single variable.

# %% [markdown]
# ### Numerical Features

# %%
plt.figure(figsize=(15, 10))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numerical_features)):
    plt.subplot(4, 2, i+1)
    sns.kdeplot(x=df[numerical_features[i]], color='blue')
    plt.xlabel(numerical_features[i])
    plt.tight_layout()

# %% [markdown]
# <font size=3>**Report**</font>
#
# * <font size=3> `Height`, `Width` and `Base Shipping price` are positively skewed</font>
#
# * <font size=3>`Weight`, `Price of Sculpture` has many outliers</font>

# %% [markdown]
# ### Categorical Features

# %%
categorical_columns = []
for i in categorical_features:
    print(f'{i}: {len(df[i].unique())}')
    if len(df[i].unique()) < 10:
        categorical_columns.append(i)
# Out:
# Customer Id: 6500
# Artist Name: 6449
# Material: 8
# International: 2
# Express Shipment: 2
# Installation Included: 2
# Transport: 4
# Fragile: 2
# Customer Information: 2
# Remote Location: 3
# Scheduled Date: 1660
# Delivery Date: 1664
# Customer Location: 6500

# %% [markdown]
# * `Customer Id`, `Artist Name`, `Customer location` have 6500 unique values, so they can be dropped
#
# * `Scheduled date` and `Delivery date` needs feature engineering

# %%
categorical_columns
# Out:
# ['Material',
#  'International',
#  'Express Shipment',
#  'Installation Included',
#  'Transport',
#  'Fragile',
#  'Customer Information',
#  'Remote Location']

# %%
# categorical columns
plt.figure(figsize=(15, 20))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
for i in range(0, len(categorical_columns)):
    plt.subplot(4, 2, i+1)
    sns.countplot(x=df[categorical_columns[i]])
    plt.xlabel(categorical_columns[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %% [markdown]
# **Insights**
#
# * `Material column` has seven unique value, which are almost equally distributed</font>
#
# * There are 6 bi-variate categorical columns</font>

# %% [markdown]
# ## Multivariate Analysis
# * Multivariate analysis is the analysis of more than one variable.

# %% [markdown]
# <font size=4>**Correlation in Numerical Features**</font>

# %%
df[(list(df.columns)[1:])].corr(numeric_only=True)
# Out:
#                      Artist Reputation    Height     Width    Weight  \
# Artist Reputation             1.000000 -0.000513 -0.009203  0.017113
# Height                       -0.000513  1.000000  0.768376  0.226543
# Width                        -0.009203  0.768376  1.000000  0.329603
# Weight                        0.017113  0.226543  0.329603  1.000000
# Price Of Sculpture            0.054286  0.200942  0.293544  0.890205
# Base Shipping Price          -0.011820  0.353858  0.332361  0.150856
# Cost                          0.067368  0.106047  0.158159  0.417263
#
#                      Price Of Sculpture  Base Shipping Price      Cost
# Artist Reputation              0.054286            -0.011820  0.067368
# Height                         0.200942             0.353858  0.106047
# Width                          0.293544             0.332361  0.158159
# Weight                         0.890205             0.150856  0.417263
# Price Of Sculpture             1.000000             0.134407  0.476231
# Base Shipping Price            0.134407             1.000000  0.053068
# Cost                           0.476231             0.053068  1.000000

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df.corr(numeric_only=True), cmap="CMRmap_r", annot=True)
plt.show()

# %% [markdown]
# **Insights**
#
# - There is a high correlation between `Height`-`Width`, and `Weight`-`Price of Sculpture`

# %% [markdown]
# ### Relationship between target and numerical columns

# %%
target_feature = 'Cost'
fig = plt.figure(figsize=(12, 24))

for i in range(0, len(numerical_features)):
    ax = plt.subplot(6, 2, i+1)
    sns.scatterplot(data= df ,y=target_feature, x=numerical_features[i], color='b')
    if df[numerical_features[i]].max() > 30000:
        plt.xlim(-1000,30000)
    if df[numerical_features[i]].max() > 3000000:
        plt.xlim(-1000,3000000)
    plt.ylim(-1000, 300000)
    plt.tight_layout()

# %% [markdown]
# **Insights**
#
# - We can observe that there seems to be very low linear relationship between the independent and dependent features
#
# - There seems to be linear relationship between Price of sculpture and the target column

# %% [markdown]
# ## Visualizing Independent columns

# %% [markdown]
# <font size=3>**Target Feature**</font>

# %%
plt.subplots(figsize=(14,7))
sns.histplot(df[target_feature], bins=200, kde=True, color = 'b')
plt.title("Cost Distribution", weight="bold",fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=12)
plt.xlabel("Cost price in millions", weight="bold", fontsize=12)
plt.xlim(-50000,300000)
plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.boxplot(df[target_feature])
plt.title("Cost Distribution", weight="bold",fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=12)
plt.xlabel("Cost price in millions", weight="bold", fontsize=12)
plt.xlim(-50000,300000);

# %% [markdown]
# **Insights**
#
# - There are outliers in the target feature and we need to transform

# %% [markdown]
# <font size=3>**How shipment type is affecting cost of shipment?**</font>

# %%
international = df.groupby('International')[target_feature].median()
international.to_frame()

plt.subplots(figsize=(14,7))
sns.barplot(x=international.index, y=international.values, ec = "black", palette="Set2")
plt.title("Shipment Type vs Median Cost", weight="bold",fontsize=20, pad=20)
plt.ylabel("Mean Cost", weight="bold", fontsize=15)
plt.xlabel("Shipment Type", weight="bold", fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_13995/3347680163.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=international.index, y=international.values, ec = "black", palette="Set2")

# %%
df['International'].value_counts()
# Out:
# International
# No     4294
# Yes    2206
# Name: count, dtype: int64

# %%
international_shipment_median = df[df['International'] == 'Yes']['Cost'].median()
domestic_shipment_median = df[df['International'] == 'No']['Cost'].median()

print(f"The difference between the median shipment price of International and domestic is {international_shipment_median-domestic_shipment_median}")
# Out:
# The difference between the median shipment price of International and domestic is 43.91500000000008

# %% [markdown]
# **Insights**
#
# - There is only a difference of 43 in the shipping cost between International and domestic, so it won't affect much at the prediction
#
# - There are much more domestic shipement than international

# %% [markdown]
# <font size=3>**How Express Shipment is affecting cost of shipment?**</font>

# %%
express_ship = df.groupby('Express Shipment')[target_feature].median()
express_ship.to_frame()

plt.subplots(figsize=(14,7))
sns.barplot(x=express_ship.index, y=express_ship.values, ec = "black", palette="Set1")
plt.title("Express Shipment vs Median Cost", weight="bold",fontsize=20, pad=20)
plt.ylabel("Mean Cost", weight="bold", fontsize=15)
plt.xlabel("Express Shipment", weight="bold", fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_13995/2741062562.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=express_ship.index, y=express_ship.values, ec = "black", palette="Set1")

# %%
df['Express Shipment'].value_counts()
# Out:
# Express Shipment
# No     4365
# Yes    2135
# Name: count, dtype: int64

# %% [markdown]
# ## Visualizing date columns

# %%
df['Scheduled Date'] = pd.to_datetime(df['Scheduled Date'])
df['Delivery Date'] = pd.to_datetime(df['Delivery Date'])
# Out:
# /tmp/ipykernel_13995/3964803925.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Scheduled Date'] = pd.to_datetime(df['Scheduled Date'])
# /tmp/ipykernel_13995/3964803925.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Delivery Date'] = pd.to_datetime(df['Delivery Date'])

# %%
df['year'] = pd.DatetimeIndex(df['Scheduled Date']).year
df['month'] = pd.DatetimeIndex(df['Scheduled Date']).month

# %%
df.head()
# Out:
#             Customer Id     Artist Name  Artist Reputation  Height  Width  \
# 0  fffe3900350033003300   Billy Jenkins               0.26    17.0    6.0
# 1  fffe3800330031003900     Jean Bryant               0.28     3.0    3.0
# 2  fffe3600370035003100    Laura Miller               0.07     8.0    5.0
# 3      fffe350031003300  Robert Chaires               0.12     9.0    NaN
# 4  fffe3900320038003400    Rosalyn Krol               0.15    17.0    6.0
#
#    Weight   Material  Price Of Sculpture  Base Shipping Price International  \
# 0  4128.0      Brass               13.91                16.27           Yes
# 1    61.0      Brass                6.83                15.00            No
# 2   237.0       Clay                4.96                21.18            No
# 3     NaN  Aluminium                5.81                16.31            No
# 4   324.0  Aluminium                3.18                11.94           Yes
#
#    ... Transport Fragile Customer Information Remote Location Scheduled Date  \
# 0  ...   Airways      No        Working Class              No     2015-06-07
# 1  ...  Roadways      No        Working Class              No     2017-03-06
# 2  ...  Roadways     Yes        Working Class             Yes     2015-03-09
# 3  ...       NaN      No              Wealthy             Yes     2015-05-24
# 4  ...   Airways      No        Working Class              No     2016-12-18
#
#   Delivery Date          Customer Location    Cost  year  month
# 0    2015-06-03     New Michelle, OH 50777 -283.29  2015      6
# 1    2017-03-05  New Michaelport, WY 12072 -159.96  2017      3
# 2    2015-03-08      Bowmanshire, WA 19241 -154.29  2015      3
# 3    2015-05-20       East Robyn, KY 86375 -161.16  2015      5
# 4    2016-12-14        Aprilside, PA 52793 -159.23  2016     12
#
# [5 rows x 22 columns]

# %%
x = df.groupby(["year", "month"])["Cost"].mean()
df_wide = x.unstack().T
df_wide.head()
# Out:
# year           2015          2016          2017          2018          2019
# month
# 1       1243.620800  12930.272703  13388.419779  47457.768519   2430.550495
# 2      34249.351818  10034.132545   3427.163673   6612.238687   3840.484630
# 3      23775.741185  10757.195810  41359.835804  20026.385455   2265.834019
# 4      94668.648276   4288.732696  26634.491452   4138.730309   8374.422975
# 5      15884.313833   4103.283514   8857.153077  17461.434118  14129.902741

# %%
df_wide[2015]
# Out:
# month
# 1      1243.620800
# 2     34249.351818
# 3     23775.741185
# 4     94668.648276
# 5     15884.313833
# 6      4480.208318
# 7      1426.520159
# 8     17085.121760
# 9      4258.188871
# 10     4979.386768
# 11    53043.073800
# 12    40081.836509
# Name: 2015, dtype: float64

# %%
for i in df_wide.columns:
    plt.subplots(figsize=(14,7))
    sns.barplot(y=df_wide[i],x=df_wide.index,ec = "black", palette="Set2")
    plt.title(str(i) + " monthly mean Shipment cost", weight="bold",fontsize=20, pad=20)
    plt.ylabel("mean", weight="bold", fontsize=11)
    plt.xlabel(i, weight="bold", fontsize=12)
    plt.show()
# Out:
# /tmp/ipykernel_13995/1296080208.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=df_wide[i],x=df_wide.index,ec = "black", palette="Set2")
# /tmp/ipykernel_13995/1296080208.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=df_wide[i],x=df_wide.index,ec = "black", palette="Set2")
# /tmp/ipykernel_13995/1296080208.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=df_wide[i],x=df_wide.index,ec = "black", palette="Set2")
# /tmp/ipykernel_13995/1296080208.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=df_wide[i],x=df_wide.index,ec = "black", palette="Set2")
# /tmp/ipykernel_13995/1296080208.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=df_wide[i],x=df_wide.index,ec = "black", palette="Set2")

# %% [markdown]
# **Insights**
#  - Monthly distribution of every year is different
#  - For 2015, 2016 and 2018 There were more cost at the start and end of the year.
#  - For 2017 and 2019 cost were high mid year.

# %%
plt.subplots(figsize=(14,7))
sns.countplot(x=df.year,ec = "black", palette="Set2")
plt.title("Year vs Shipment Orders", weight="bold",fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=11)
plt.xlabel("Year", weight="bold", fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_13995/3063941337.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df.year,ec = "black", palette="Set2")

# %%
plt.subplots(figsize=(14,7))
sns.countplot(x=df.month,ec = "black", palette="Set2")
plt.title("Customer Information vs Median Cost", weight="bold",fontsize=20, pad=20)
plt.ylabel("Mean Cost", weight="bold", fontsize=15)
plt.xlabel("Customer Financial Condition", weight="bold", fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_13995/1846697422.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df.month,ec = "black", palette="Set2")

# %% [markdown]
# # Final Report

# %% [markdown]
# * The `Cost` column is the target to predict.
# * The target variable here is continuous.
# * There are outliers in some columns we have to remove outliers.
# * `date` column should be configured to extract `year` and `month`.
# * Null values in `Artist Reputation`, `Height`, `Width`, `Weight`, `Material`, `Transport`, `Remote Location` needs to be handled
