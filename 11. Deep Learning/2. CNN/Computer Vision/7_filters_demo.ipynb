# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2

# %%
img_path = "/content/images.jfif"

# %% [markdown]
# # Load Matplotlib

# %%
bird1 = mpimg.imread(img_path)

# %%
bird1
# Out:
# array([[[174, 172, 173],
#         [174, 172, 173],
#         [174, 172, 173],
#         ...,
#         [168, 172, 181],
#         [168, 172, 181],
#         [168, 172, 181]],
#
#        [[174, 172, 173],
#         [174, 172, 173],
#         [174, 172, 173],
#         ...,
#         [168, 172, 181],
#         [168, 172, 181],
#         [168, 172, 181]],
#
#        [[174, 172, 173],
#         [174, 172, 173],
#         [174, 172, 173],
#         ...,
#         [168, 172, 181],
#         [168, 172, 181],
#         [168, 172, 181]],
#
#        ...,
#
#        [[147,  80,   2],
#         [148,  81,   2],
#         [150,  82,   1],
#         ...,
#         [161, 180, 186],
#         [161, 180, 186],
#         [161, 180, 187]],
#
#        [[145,  77,   2],
#         [145,  78,   0],
#         [148,  79,   1],
#         ...,
#         [161, 180, 186],
#         [161, 180, 186],
#         [161, 180, 186]],
#
#        [[143,  75,   0],
#         [144,  77,   0],
#         [147,  78,   1],
#         ...,
#         [161, 180, 186],
#         [161, 180, 186],
#         [161, 180, 186]]], dtype=uint8)

# %%
plt.imshow(bird1)

# %%
bird1.shape
# Out:
# (640, 479, 3)

# %% [markdown]
# # Load OpenCV

# %%
bird1_cv2 = cv2.imread(img_path)

# %%
bird1_cv2
# Out:
# array([[[173, 172, 174],
#         [173, 172, 174],
#         [173, 172, 174],
#         ...,
#         [181, 172, 168],
#         [181, 172, 168],
#         [181, 172, 168]],
#
#        [[173, 172, 174],
#         [173, 172, 174],
#         [173, 172, 174],
#         ...,
#         [181, 172, 168],
#         [181, 172, 168],
#         [181, 172, 168]],
#
#        [[173, 172, 174],
#         [173, 172, 174],
#         [173, 172, 174],
#         ...,
#         [181, 172, 168],
#         [181, 172, 168],
#         [181, 172, 168]],
#
#        ...,
#
#        [[  2,  80, 147],
#         [  2,  81, 148],
#         [  1,  82, 150],
#         ...,
#         [186, 180, 161],
#         [186, 180, 161],
#         [187, 180, 161]],
#
#        [[  2,  77, 145],
#         [  0,  78, 145],
#         [  1,  79, 148],
#         ...,
#         [186, 180, 161],
#         [186, 180, 161],
#         [186, 180, 161]],
#
#        [[  0,  75, 143],
#         [  0,  77, 144],
#         [  1,  78, 147],
#         ...,
#         [186, 180, 161],
#         [186, 180, 161],
#         [186, 180, 161]]], dtype=uint8)

# %% [markdown]
# 1. OpenCV reads - BGR
# 2. Matplotlib reads - RGB

# %%
bird1_cv2_BGR_RGB = cv2.cvtColor(bird1_cv2, cv2.COLOR_BGR2RGB)
plt.imshow(bird1_cv2_BGR_RGB)

# %%
bird1_cv2_BGR_GRAY = cv2.cvtColor(bird1_cv2, cv2.COLOR_BGR2GRAY)
plt.imshow(bird1_cv2_BGR_GRAY, cmap = "gray")

# %%
bird1_cv2_BGR_GRAY.shape
# Out:
# (640, 479)

# %%
bird1_cv2_BGR_GRAY.min()
# Out:
# np.uint8(0)

# %%
bird1_cv2_BGR_GRAY.max()
# Out:
# np.uint8(255)

# %% [markdown]
# # Understanding composition of colored images

# %%
def viusalize_RGB_channel(imgArray=None, figsize=(10,7)):
  # splitting the RGB components
  B, G, R = cv2.split(imgArray)

  # create zero matrix of shape of image
  Z = np.zeros(B.shape, dtype=B.dtype) # can use any channel

  # init subplots
  fig, ax = plt.subplots(2,2, figsize=figsize)

  # plotting the actual image and RGB images
  [axi.set_axis_off() for axi in ax.ravel()]

  ax[0,0].set_title("Original Image")
  # ax[0,0].set_axis_off()
  ax[0,0].imshow(cv2.merge((R,G,B)))

  ax[0,1].set_title("Red Ch Image")
  ax[0,1].imshow(cv2.merge((R,Z,Z)))

  ax[1,0].set_title("Green Ch Image")
  ax[1,0].imshow(cv2.merge((Z,G,Z)))

  ax[1,1].set_title("Blue Ch Image")
  ax[1,1].imshow(cv2.merge((Z,Z,B)))

# %%
bird1_cv2
# Out:
# array([[[173, 172, 174],
#         [173, 172, 174],
#         [173, 172, 174],
#         ...,
#         [181, 172, 168],
#         [181, 172, 168],
#         [181, 172, 168]],
#
#        [[173, 172, 174],
#         [173, 172, 174],
#         [173, 172, 174],
#         ...,
#         [181, 172, 168],
#         [181, 172, 168],
#         [181, 172, 168]],
#
#        [[173, 172, 174],
#         [173, 172, 174],
#         [173, 172, 174],
#         ...,
#         [181, 172, 168],
#         [181, 172, 168],
#         [181, 172, 168]],
#
#        ...,
#
#        [[  2,  80, 147],
#         [  2,  81, 148],
#         [  1,  82, 150],
#         ...,
#         [186, 180, 161],
#         [186, 180, 161],
#         [187, 180, 161]],
#
#        [[  2,  77, 145],
#         [  0,  78, 145],
#         [  1,  79, 148],
#         ...,
#         [186, 180, 161],
#         [186, 180, 161],
#         [186, 180, 161]],
#
#        [[  0,  75, 143],
#         [  0,  77, 144],
#         [  1,  78, 147],
#         ...,
#         [186, 180, 161],
#         [186, 180, 161],
#         [186, 180, 161]]], dtype=uint8)

# %%
viusalize_RGB_channel(imgArray = bird1_cv2)

# %% [markdown]
# # Create a random image

# %%
random_colored_img = np.random.randint(0, 255, (6,6,3))
random_colored_img.shape
# Out:
# (6, 6, 3)

# %%
random_colored_img
# Out:
# array([[[ 77, 200,  40],
#         [133,  30,  68],
#         [122, 244,  20],
#         [ 39,  32, 107],
#         [120, 229, 148],
#         [226, 209, 176]],
#
#        [[ 85,  38,  79],
#         [146,  73, 145],
#         [158,   8, 151],
#         [204,  56, 141],
#         [127,  25,  25],
#         [114, 214, 234]],
#
#        [[248,  96,  91],
#         [113,  69, 116],
#         [112, 175, 177],
#         [ 27, 218, 178],
#         [ 35,  90, 213],
#         [ 23, 184, 155]],
#
#        [[228, 128,  65],
#         [ 66,   3, 112],
#         [ 11,  23, 135],
#         [ 35,   5, 254],
#         [250,  49, 171],
#         [101,  43,  56]],
#
#        [[237, 220, 132],
#         [140, 145, 167],
#         [180,  58,  42],
#         [196, 160, 100],
#         [179,  58,  53],
#         [102,  39,   2]],
#
#        [[138, 133,  49],
#         [101, 194, 166],
#         [233,  90, 209],
#         [220, 191,  43],
#         [ 20,  69, 213],
#         [ 80, 177, 246]]])

# %%
plt.imshow(random_colored_img)

# %%
viusalize_RGB_channel(imgArray = random_colored_img)

# %% [markdown]
# # Understanding filters

# %%
sobel = np.array([[ 1, 0,-1],
                  [ 2, 0,-2],
                  [ 1, 0,-1]])

print("highlighting Vertical edges:\n", sobel)
# Out:
# highlighting Vertical edges:
#  [[ 1  0 -1]
#  [ 2  0 -2]
#  [ 1  0 -1]]

# %%
print("highlighting Horizontal edges:\n", sobel.T)
# Out:
# highlighting Horizontal edges:
#  [[ 1  2  1]
#  [ 0  0  0]
#  [-1 -2 -1]]

# %%
example1 = [
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,255,255,255,255],
    [0,0,0,0,255,255,255,255,255,255,255,255],
    [0,0,0,0,255,255,255,255,255,255,255,255],
    [0,0,0,0,255,255,255,255,255,255,255,255],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
    [0,0,0,0,255,255,255,255,0,0,0,0],
            ]

example1 = np.array(example1)

# %%
example1
# Out:
# array([[  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 255, 255, 255, 255, 255, 255, 255, 255],
#        [  0,   0,   0,   0, 255, 255, 255, 255, 255, 255, 255, 255],
#        [  0,   0,   0,   0, 255, 255, 255, 255, 255, 255, 255, 255],
#        [  0,   0,   0,   0, 255, 255, 255, 255, 255, 255, 255, 255],
#        [  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0],
#        [  0,   0,   0,   0, 255, 255, 255, 255,   0,   0,   0,   0]])

# %%
plt.imshow(example1, cmap="gray")

# %%
def simple_conv(imgFilter=None, picture=None):
  # extract the shape of the image
  p_row, p_col = picture.shape

  k = imgFilter.shape[0] # k =3

  temp = list()

  stride = 1

  # resulant image size
  final_cols = (p_col - k)//stride + 1
  final_rows = (p_row - k)//stride + 1

  # take vertically down stride across row by row
  for v_stride in range(final_rows):
    # take horizontal right stride across col by col
    for h_stride in range(final_cols):
      target_area_of_pic = picture[v_stride: v_stride + k, h_stride: h_stride + k]
      z = sum(sum(imgFilter * target_area_of_pic))
      temp.append(z)

  resulant_image = np.array(temp).reshape(final_rows, final_cols)
  return resulant_image

# %%
results = simple_conv(imgFilter=sobel, picture=example1)

# %%
results
# Out:
# array([[    0,     0, -1020, -1020,     0,     0,  1020,  1020,     0,
#             0],
#        [    0,     0, -1020, -1020,     0,     0,  1020,  1020,     0,
#             0],
#        [    0,     0, -1020, -1020,     0,     0,   765,   765,     0,
#             0],
#        [    0,     0, -1020, -1020,     0,     0,   255,   255,     0,
#             0],
#        [    0,     0, -1020, -1020,     0,     0,     0,     0,     0,
#             0],
#        [    0,     0, -1020, -1020,     0,     0,     0,     0,     0,
#             0],
#        [    0,     0, -1020, -1020,     0,     0,   255,   255,     0,
#             0],
#        [    0,     0, -1020, -1020,     0,     0,   765,   765,     0,
#             0],
#        [    0,     0, -1020, -1020,     0,     0,  1020,  1020,     0,
#             0],
#        [    0,     0, -1020, -1020,     0,     0,  1020,  1020,     0,
#             0]])

# %% [markdown]
# ## virtical

# %%
plt.imshow(results, cmap="gray")

# %%
plt.imshow(example1, cmap="gray")

# %%
result = simple_conv(imgFilter=sobel.T, picture=example1)

# %% [markdown]
# ## horizontal

# %%
plt.imshow(result, cmap="gray")

# %% [markdown]
# ## Applying the original image

# %%
bird1_cv2_BGR_GRAY = cv2.cvtColor(bird1_cv2, cv2.COLOR_BGR2GRAY)
plt.imshow(bird1_cv2_BGR_GRAY, cmap="gray")

# %% [markdown]
# ## virtical

# %%
result = simple_conv(imgFilter=sobel, picture=bird1_cv2_BGR_GRAY)
plt.imshow(result, cmap="gray")

# %% [markdown]
# ## horizontal

# %%
result = simple_conv(imgFilter=sobel.T, picture=bird1_cv2_BGR_GRAY)
plt.imshow(result, cmap="gray")
