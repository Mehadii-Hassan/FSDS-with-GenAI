# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %% [markdown]
# # Dog image

# %%
img_path = '/content/dog.jfif'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
x
# Out:
# array([[[[-99.939   , -76.779   , -89.68    ],
#          [-99.939   , -76.779   , -89.68    ],
#          [-98.939   , -75.779   , -88.68    ],
#          ...,
#          [-93.939   , -79.779   , -90.68    ],
#          [-93.939   , -79.779   , -90.68    ],
#          [-93.939   , -79.779   , -90.68    ]],
#
#         [[-99.939   , -76.779   , -89.68    ],
#          [-99.939   , -76.779   , -89.68    ],
#          [-98.939   , -75.779   , -88.68    ],
#          ...,
#          [-93.939   , -79.779   , -90.68    ],
#          [-93.939   , -79.779   , -90.68    ],
#          [-93.939   , -79.779   , -90.68    ]],
#
#         [[-99.939   , -76.779   , -89.68    ],
#          [-99.939   , -76.779   , -89.68    ],
#          [-98.939   , -75.779   , -88.68    ],
#          ...,
#          [-94.939   , -80.779   , -91.68    ],
#          [-94.939   , -80.779   , -91.68    ],
#          [-94.939   , -80.779   , -91.68    ]],
#
#         ...,
#
#         [[-29.939003,  38.221   ,  34.32    ],
#          [-29.939003,  40.221   ,  35.32    ],
#          [-35.939003,  41.221   ,  35.32    ],
#          ...,
#          [-48.939003,  28.221   ,  16.32    ],
#          [-47.939003,  29.221   ,  17.32    ],
#          [-45.939003,  31.221   ,  19.32    ]],
#
#         [[-30.939003,  37.221   ,  33.32    ],
#          [-30.939003,  39.221   ,  34.32    ],
#          [-36.939003,  40.221   ,  34.32    ],
#          ...,
#          [-50.939003,  26.221   ,  14.32    ],
#          [-48.939003,  28.221   ,  16.32    ],
#          [-45.939003,  31.221   ,  19.32    ]],
#
#         [[-30.939003,  37.221   ,  33.32    ],
#          [-30.939003,  39.221   ,  34.32    ],
#          [-36.939003,  40.221   ,  34.32    ],
#          ...,
#          [-50.939003,  26.221   ,  14.32    ],
#          [-48.939003,  28.221   ,  16.32    ],
#          [-45.939003,  31.221   ,  19.32    ]]]], dtype=float32)

# %%
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Predicted: [('n02089973', 'English_foxhound', np.float32(0.60643846)), ('n02088364', 'beagle', np.float32(0.11901983)), ('n02107908', 'Appenzeller', np.float32(0.08893753))]

# %% [markdown]
# # Cat image

# %%
img_path = '/content/cat.jfif'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
x
# Out:
# array([[[[ 13.060997 ,  67.221    ,  53.32     ],
#          [ 13.060997 ,  67.221    ,  53.32     ],
#          [ 13.060997 ,  67.221    ,  53.32     ],
#          ...,
#          [-62.939003 , -33.779    , -51.68     ],
#          [-32.939003 ,  -5.7789993, -23.68     ],
#          [-15.939003 ,   8.221001 ,  -6.6800003]],
#
#         [[ 13.060997 ,  67.221    ,  53.32     ],
#          [ 13.060997 ,  67.221    ,  53.32     ],
#          [ 13.060997 ,  67.221    ,  53.32     ],
#          ...,
#          [-62.939003 , -33.779    , -51.68     ],
#          [-32.939003 ,  -5.7789993, -23.68     ],
#          [-15.939003 ,   8.221001 ,  -6.6800003]],
#
#         [[ 11.060997 ,  65.221    ,  51.32     ],
#          [ 10.060997 ,  65.221    ,  51.32     ],
#          [ 11.060997 ,  65.221    ,  51.32     ],
#          ...,
#          [-39.939003 ,  -9.778999 , -27.68     ],
#          [-13.939003 ,  14.221001 ,  -0.6800003],
#          [  4.060997 ,  28.221    ,  13.32     ]],
#
#         ...,
#
#         [[-68.939    ,  35.221    ,   1.3199997],
#          [-70.939    ,  33.221    ,  -0.6800003],
#          [-73.939    ,  32.221    ,  -2.6800003],
#          ...,
#          [-86.939    , -18.779    , -64.68     ],
#          [-91.939    , -21.779    , -67.68     ],
#          [-94.939    , -22.779    , -67.68     ]],
#
#         [[-70.939    ,  33.221    ,  -0.6800003],
#          [-72.939    ,  31.221    ,  -2.6800003],
#          [-74.939    ,  31.221    ,  -3.6800003],
#          ...,
#          [-90.939    , -22.779    , -68.68     ],
#          [-95.939    , -25.779    , -71.68     ],
#          [-97.939    , -27.779    , -72.68     ]],
#
#         [[-70.939    ,  33.221    ,  -0.6800003],
#          [-72.939    ,  31.221    ,  -2.6800003],
#          [-74.939    ,  31.221    ,  -3.6800003],
#          ...,
#          [-90.939    , -22.779    , -68.68     ],
#          [-95.939    , -25.779    , -71.68     ],
#          [-97.939    , -27.779    , -72.68     ]]]], dtype=float32)

# %%
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Predicted: [('n02124075', 'Egyptian_cat', np.float32(0.25862992)), ('n02109961', 'Eskimo_dog', np.float32(0.14535175)), ('n02326432', 'hare', np.float32(0.10595597))]

# %% [markdown]
# # Car image

# %%
img_path = '/content/car.jfif'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
x
# Out:
# array([[[[-102.939   , -115.779   , -122.68    ],
#          [-102.939   , -115.779   , -122.68    ],
#          [-102.939   , -115.779   , -122.68    ],
#          ...,
#          [ -94.939   , -107.779   , -114.68    ],
#          [ -93.939   , -106.779   , -113.68    ],
#          [ -97.939   , -109.779   , -118.68    ]],
#
#         [[-102.939   , -115.779   , -122.68    ],
#          [-102.939   , -115.779   , -122.68    ],
#          [-102.939   , -115.779   , -122.68    ],
#          ...,
#          [ -93.939   , -106.779   , -113.68    ],
#          [ -93.939   , -106.779   , -113.68    ],
#          [ -80.939   ,  -92.779   , -101.68    ]],
#
#         [[-102.939   , -115.779   , -122.68    ],
#          [-102.939   , -115.779   , -122.68    ],
#          [-102.939   , -115.779   , -122.68    ],
#          ...,
#          [ -72.939   ,  -85.779   ,  -92.68    ],
#          [ -76.939   ,  -89.779   ,  -96.68    ],
#          [ -96.939   , -106.779   , -115.68    ]],
#
#         ...,
#
#         [[ -65.939   ,  -57.779   ,  -33.68    ],
#          [ -57.939003,  -49.779   ,  -25.68    ],
#          [ -51.939003,  -43.779   ,  -19.68    ],
#          ...,
#          [ -88.939   ,  -82.779   ,  -74.68    ],
#          [ -88.939   ,  -82.779   ,  -74.68    ],
#          [ -95.939   ,  -86.779   ,  -82.68    ]],
#
#         [[ -54.939003,  -45.779   ,  -24.68    ],
#          [ -59.939003,  -50.779   ,  -29.68    ],
#          [ -60.939003,  -51.779   ,  -30.68    ],
#          ...,
#          [ -76.939   ,  -68.779   ,  -60.68    ],
#          [ -77.939   ,  -69.779   ,  -61.68    ],
#          [ -88.939   ,  -77.779   ,  -72.68    ]],
#
#         [[ -72.939   ,  -62.779   ,  -43.68    ],
#          [ -84.939   ,  -74.779   ,  -55.68    ],
#          [ -81.939   ,  -71.779   ,  -52.68    ],
#          ...,
#          [ -98.939   ,  -89.779   ,  -84.68    ],
#          [ -96.939   ,  -88.779   ,  -80.68    ],
#          [ -94.939   ,  -83.779   ,  -78.68    ]]]], dtype=float32)

# %%
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Predicted: [('n03100240', 'convertible', np.float32(0.8605753)), ('n04037443', 'racer', np.float32(0.03948824)), ('n04285008', 'sports_car', np.float32(0.025928108))]
