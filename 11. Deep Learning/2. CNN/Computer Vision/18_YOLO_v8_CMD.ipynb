# %% [markdown]
# ###Modes:
# train, val, predict
#
# ###Tasks:
# detect, segment, classify
#
# ###Data:
# Format can be differ for task type, Supports data.yaml, data_folder, data_name

# %% [markdown]
# # Installation

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 37.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## CMD

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# # 1. Detection:

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="/content/cat_dog_human_image.jpg"
# Out:
# ...
# Ultralytics 8.4.102 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/cat_dog_human_image.jpg: 448x640 2 persons, 1 cat, 1 dog, 95.1ms
# Speed: 14.6ms preprocess, 95.1ms inference, 42.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 2. Segmentation:

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source="/content/cat_dog_human_image.jpg"
# Out:
# ...
# Ultralytics 8.4.102 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n-seg summary (fused): 85 layers, 3,404,320 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/1 /content/cat_dog_human_image.jpg: 448x640 2 persons, 1 cat, 1 dog, 58.1ms
# Speed: 3.0ms preprocess, 58.1ms inference, 65.2ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # 3. Classification:

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source="/content/cat_dog_human_image.jpg"
# Out:
# ...
# Ultralytics 8.4.102 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n-cls summary (fused): 30 layers, 2,715,880 parameters, 0 gradients, 4.3 GFLOPs
#
# ...
# image 1/1 /content/cat_dog_human_image.jpg: 224x224 bull_mastiff 0.16, Rhodesian_ridgeback 0.15, muzzle 0.14, boxer 0.12, pug 0.06, 3.1ms
# Speed: 19.9ms preprocess, 3.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to /content/runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
