# %%
print("ok")
# Out:
# Running cells with 'venv (Python 3.11.14)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\Mehedi\Desktop\FSDS with Gen AI\FSDS-with-GenAI\Practice\DataBase\SQL (MySQL)\venv ipykernel --update-deps --force-reinstall'

# %%
print("ok")
