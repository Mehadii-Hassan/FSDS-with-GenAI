# %% [markdown]
# # what should we do?
# > 1. Login mongodb atlas
# > 2. Create a project
# > 3. Create Cluster
# > 4. For connection : pip install pymongo

# %%
mongodb+srv://mehadicse01:624234@cluster0.ubba13q.mongodb.net/?appName=Cluster0

# %%
import pandas as pd

pd.read_csv("glass.data")
# Out:
# ok
